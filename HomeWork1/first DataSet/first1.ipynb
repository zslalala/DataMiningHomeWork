# %% [markdown]
# ## 首先观察数据集情况，然后观察数值数据的各个分位点及中值等情况

# %%
import os
import pandas as pd
import numpy as  np
def load_data():
    csv_path = "cbg_patterns.csv"
    return pd.read_csv(csv_path)
data = load_data()
data.describe()
# Out:
#        census_block_group  date_range_start  date_range_end  raw_visit_count  \
# count        2.207340e+05      2.207350e+05    2.207350e+05     2.206290e+05
# mean         2.870864e+11      1.538352e+09    1.541030e+09     4.793066e+04
# std          1.640723e+11      0.000000e+00    0.000000e+00     6.252655e+04
# min          1.001020e+10      1.538352e+09    1.541030e+09     6.000000e+01
# 25%          1.312101e+11      1.538352e+09    1.541030e+09     1.704200e+04
# 50%          2.901900e+11      1.538352e+09    1.541030e+09     3.064000e+04
# 75%          4.200349e+11      1.538352e+09    1.541030e+09     5.667800e+04
# max          7.803099e+11      1.538352e+09    1.541030e+09     7.179900e+06
#
#        raw_visitor_count  distance_from_home
# count       2.206290e+05        2.205180e+05
# mean        1.182032e+04        3.511280e+04
# std         3.045832e+04        9.973193e+04
# min         5.000000e+01        7.060000e+02
# 25%         3.430000e+03        8.584000e+03
# ...

# %% [markdown]
# ## 观察数据集的整体情况

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220735 entries, 0 to 220734
# Data columns (total 13 columns):
# census_block_group          220734 non-null float64
# date_range_start            220735 non-null int64
# date_range_end              220735 non-null int64
# raw_visit_count             220629 non-null float64
# raw_visitor_count           220629 non-null float64
# visitor_home_cbgs           220735 non-null object
# visitor_work_cbgs           220735 non-null object
# distance_from_home          220518 non-null float64
# related_same_day_brand      220735 non-null object
# related_same_month_brand    220735 non-null object
# top_brands                  220735 non-null object
# popularity_by_hour          220735 non-null object
# popularity_by_day           220735 non-null object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 21.9+ MB

# %% [markdown]
# ## 观察数据集的各个文本属性的取值情况

# %%
data["visitor_home_cbgs"].value_counts()
# Out:
# {}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
# ...

# %%
data["visitor_work_cbgs"].value_counts()
# Out:
# {}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            51152
# ...

# %%
data["related_same_day_brand"].value_counts()
# Out:
# []                                                                                                                                   35542
# ["Dunkin' Donuts"]                                                                                                                    7010
# ["starbucks"]                                                                                                                         4178
# ["walmart"]                                                                                                                           3054
# ["mcdonalds"]                                                                                                                         2911
# ["Wawa"]                                                                                                                              2831
# ["7-Eleven US"]                                                                                                                       2403
# ...

# %%
data["related_same_month_brand"].value_counts()
# Out:
# []                                                                                                                                                                                                   2983
# ["SmartStyle Family Hair Salons"]                                                                                                                                                                     335
# ["Department of Veterans Affairs"]                                                                                                                                                                    156
# ["H&R Block"]                                                                                                                                                                                         134
# ...

# %%
data["top_brands"].value_counts()
# Out:
# []                                                                                                                                                                                                 74540
# ["United States Postal Service (USPS)"]                                                                                                                                                             5352
# ["Aflac (American Family Life Assurance)"]                                                                                                                                                          1517
# ["Dollar General"]                                                                                                                                                                                  1308
# ...

# %%
data["popularity_by_hour"].value_counts()
# Out:
# []                                                                                                                                                   106
# [571,559,563,560,564,574,591,623,648,655,731,833,910,895,895,884,800,701,641,597,615,615,585,584]                                                      1
# [5080,4517,4125,4013,4179,4425,6544,9051,10885,12542,14875,17763,20721,21626,21269,21474,22279,22906,22308,19867,15674,11245,8097,6203]                1
# [1661,1494,1440,1290,1602,1844,2585,4264,4721,5088,5553,6128,6226,6201,6133,6445,6609,5931,5213,4287,3461,2777,2222,1822]                              1
# [3264,3165,2899,2896,2797,3134,3895,4643,4593,4499,4557,4974,5232,5021,4960,5161,5200,5703,5354,4746,4386,4072,3792,3506]                              1
# [3669,3552,3508,3498,3610,4057,4955,6089,4994,4208,4191,4099,4464,4539,4706,5440,6404,6768,5901,5078,4738,4413,4119,3871]                              1
# ...

# %%
data["popularity_by_day"].value_counts()
# Out:
# {}                                                                                                                           106
# {"Monday":10402,"Tuesday":10489,"Wednesday":10378,"Thursday":8540,"Friday":9233,"Saturday":7951,"Sunday":6618}                 1
# {"Monday":2494,"Tuesday":2508,"Wednesday":2425,"Thursday":2091,"Friday":2475,"Saturday":2458,"Sunday":1902}                    1
# {"Monday":2624,"Tuesday":2773,"Wednesday":2536,"Thursday":2071,"Friday":2090,"Saturday":1812,"Sunday":1843}                    1
# {"Monday":4557,"Tuesday":4729,"Wednesday":5164,"Thursday":3819,"Friday":4387,"Saturday":3433,"Sunday":3137}                    1
# {"Monday":1554,"Tuesday":1684,"Wednesday":1439,"Thursday":1305,"Friday":1371,"Saturday":1557,"Sunday":1354}                    1
# {"Monday":5747,"Tuesday":5843,"Wednesday":5801,"Thursday":4789,"Friday":5476,"Saturday":4242,"Sunday":3809}                    1
# ...
